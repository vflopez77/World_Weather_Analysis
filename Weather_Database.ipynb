# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Use the citipy module to determine city based on latitude and longitude.
import citipy
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Build basic URL
from config import weather_base_url
url = f"{weather_base_url}{weather_api_key}"

# %%
# Get all the city weather data
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description})
                          #                          "Date": city_date})
        # If an error is experienced, skip the city.
    except:
        print(f"City {city} not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yenagoa
# Processing Record 2 of Set 1 | oktyabrskoye
# Processing Record 3 of Set 1 | gat
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | ornskoldsvik
# Processing Record 6 of Set 1 | harper
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | marawi
# Processing Record 9 of Set 1 | vanimo
# Processing Record 10 of Set 1 | nguiu
# City nguiu not found. Skipping...
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | lolodorf
# Processing Record 13 of Set 1 | penzance
# Processing Record 14 of Set 1 | turukhansk
# Processing Record 15 of Set 1 | ixtapa
# Processing Record 16 of Set 1 | isangel
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | palmer
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | solnechnyy
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | jalu
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | salalah
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | qaqortoq
# Processing Record 28 of Set 1 | port hardy
# Processing Record 29 of Set 1 | hobyo
# Processing Record 30 of Set 1 | flinders
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | markala
# Processing Record 33 of Set 1 | svetlaya
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | ambilobe
# Processing Record 37 of Set 1 | grand river south east
# City grand river south east not found. Skipping...
# Processing Record 38 of Set 1 | talnakh
# Processing Record 39 of Set 1 | klaksvik
# Processing Record 40 of Set 1 | faanui
# Processing Record 41 of Set 1 | vestmanna
# Processing Record 42 of Set 1 | caravelas
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | samusu
# City samusu not found. Skipping...
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | diego de almagro
# Processing Record 48 of Set 1 | aykhal
# Processing Record 49 of Set 1 | lavrentiya
# Processing Record 50 of Set 1 | petatlan
# Processing Record 1 of Set 2 | illoqqortoormiut
# City illoqqortoormiut not found. Skipping...
# Processing Record 2 of Set 2 | udachnyy
# Processing Record 3 of Set 2 | labuhan
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | huanren
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | fortuna
# Processing Record 8 of Set 2 | manta
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | souillac
# Processing Record 11 of Set 2 | tungor
# Processing Record 12 of Set 2 | pangnirtung
# Processing Record 13 of Set 2 | avera
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | berlevag
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | mount hagen
# Processing Record 18 of Set 2 | deputatskiy
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | tuatapere
# Processing Record 21 of Set 2 | yerbogachen
# Processing Record 22 of Set 2 | jacareacanga
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | ahipara
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | san cristobal
# Processing Record 27 of Set 2 | portlethen
# Processing Record 28 of Set 2 | buraydah
# Processing Record 29 of Set 2 | ponta do sol
# Processing Record 30 of Set 2 | omutinskoye
# City omutinskoye not found. Skipping...
# Processing Record 31 of Set 2 | hofn
# Processing Record 32 of Set 2 | ushuaia
# Processing Record 33 of Set 2 | mount isa
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | sterling
# Processing Record 37 of Set 2 | kitimat
# Processing Record 38 of Set 2 | dogondoutchi
# Processing Record 39 of Set 2 | tezu
# Processing Record 40 of Set 2 | khatanga
# Processing Record 41 of Set 2 | mayo
# Processing Record 42 of Set 2 | marcona
# City marcona not found. Skipping...
# Processing Record 43 of Set 2 | duz
# City duz not found. Skipping...
# Processing Record 44 of Set 2 | saldanha
# Processing Record 45 of Set 2 | savannah bight
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | dikson
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | puerto escondido
# Processing Record 1 of Set 3 | margate
# Processing Record 2 of Set 3 | hithadhoo
# Processing Record 3 of Set 3 | bocas del toro
# Processing Record 4 of Set 3 | inuvik
# Processing Record 5 of Set 3 | kavieng
# Processing Record 6 of Set 3 | tarko-sale
# Processing Record 7 of Set 3 | ostrovnoy
# Processing Record 8 of Set 3 | atasu
# Processing Record 9 of Set 3 | strathpeffer
# Processing Record 10 of Set 3 | mawlaik
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | rock springs
# Processing Record 13 of Set 3 | lasa
# Processing Record 14 of Set 3 | cherskiy
# Processing Record 15 of Set 3 | sagauli
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | alihe
# Processing Record 18 of Set 3 | tsihombe
# City tsihombe not found. Skipping...
# Processing Record 19 of Set 3 | vaitupu
# City vaitupu not found. Skipping...
# Processing Record 20 of Set 3 | melfi
# Processing Record 21 of Set 3 | san jose
# Processing Record 22 of Set 3 | grand gaube
# Processing Record 23 of Set 3 | evensk
# Processing Record 24 of Set 3 | guerrero negro
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | saint george
# Processing Record 27 of Set 3 | bluff
# Processing Record 28 of Set 3 | kahului
# Processing Record 29 of Set 3 | aflu
# City aflu not found. Skipping...
# Processing Record 30 of Set 3 | vao
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | veraval
# Processing Record 33 of Set 3 | denpasar
# Processing Record 34 of Set 3 | qeshm
# Processing Record 35 of Set 3 | broome
# Processing Record 36 of Set 3 | nikolskoye
# Processing Record 37 of Set 3 | namibe
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | dongsheng
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | ormara
# Processing Record 42 of Set 3 | ayan
# Processing Record 43 of Set 3 | bathsheba
# Processing Record 44 of Set 3 | raudeberg
# Processing Record 45 of Set 3 | tuktoyaktuk
# Processing Record 46 of Set 3 | zuwarah
# Processing Record 47 of Set 3 | okhotsk
# Processing Record 48 of Set 3 | yuanping
# Processing Record 49 of Set 3 | belmonte
# Processing Record 50 of Set 3 | saskylakh
# Processing Record 1 of Set 4 | attawapiskat
# City attawapiskat not found. Skipping...
# Processing Record 2 of Set 4 | yulara
# Processing Record 3 of Set 4 | thompson
# Processing Record 4 of Set 4 | esso
# Processing Record 5 of Set 4 | pevek
# Processing Record 6 of Set 4 | rio gallegos
# Processing Record 7 of Set 4 | diban
# Processing Record 8 of Set 4 | verkhnyaya balkariya
# Processing Record 9 of Set 4 | narsaq
# Processing Record 10 of Set 4 | abha
# Processing Record 11 of Set 4 | lezajsk
# Processing Record 12 of Set 4 | iqaluit
# Processing Record 13 of Set 4 | bambous virieux
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | luau
# Processing Record 16 of Set 4 | hamilton
# Processing Record 17 of Set 4 | rivers
# Processing Record 18 of Set 4 | joshimath
# Processing Record 19 of Set 4 | laguna
# Processing Record 20 of Set 4 | taolanaro
# City taolanaro not found. Skipping...
# Processing Record 21 of Set 4 | touros
# Processing Record 22 of Set 4 | batemans bay
# Processing Record 23 of Set 4 | praia da vitoria
# Processing Record 24 of Set 4 | mys shmidta
# City mys shmidta not found. Skipping...
# Processing Record 25 of Set 4 | urengoy
# Processing Record 26 of Set 4 | zawiercie
# Processing Record 27 of Set 4 | banfora
# Processing Record 28 of Set 4 | buncrana
# Processing Record 29 of Set 4 | skara
# Processing Record 30 of Set 4 | miyako
# Processing Record 31 of Set 4 | constitucion
# Processing Record 32 of Set 4 | tripoli
# Processing Record 33 of Set 4 | conceicao do araguaia
# Processing Record 34 of Set 4 | roma
# Processing Record 35 of Set 4 | san patricio
# Processing Record 36 of Set 4 | lake jackson
# Processing Record 37 of Set 4 | tutoia
# Processing Record 38 of Set 4 | krasnokholmskiy
# Processing Record 39 of Set 4 | guasdualito
# Processing Record 40 of Set 4 | lensk
# Processing Record 41 of Set 4 | acapulco
# Processing Record 42 of Set 4 | miura
# Processing Record 43 of Set 4 | salinas
# Processing Record 44 of Set 4 | te anau
# Processing Record 45 of Set 4 | belushya guba
# City belushya guba not found. Skipping...
# Processing Record 46 of Set 4 | kaduna
# Processing Record 47 of Set 4 | malanje
# Processing Record 48 of Set 4 | praia
# Processing Record 49 of Set 4 | rio branco
# Processing Record 50 of Set 4 | vila
# Processing Record 1 of Set 5 | lakatoro
# Processing Record 2 of Set 5 | carndonagh
# Processing Record 3 of Set 5 | kichera
# Processing Record 4 of Set 5 | ancud
# Processing Record 5 of Set 5 | thinadhoo
# Processing Record 6 of Set 5 | paramonga
# Processing Record 7 of Set 5 | hambantota
# Processing Record 8 of Set 5 | chaochou
# City chaochou not found. Skipping...
# Processing Record 9 of Set 5 | greenwood
# Processing Record 10 of Set 5 | qasigiannguit
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | jutai
# Processing Record 13 of Set 5 | kyra
# Processing Record 14 of Set 5 | oistins
# Processing Record 15 of Set 5 | shihezi
# Processing Record 16 of Set 5 | gidole
# Processing Record 17 of Set 5 | chicama
# Processing Record 18 of Set 5 | dubbo
# Processing Record 19 of Set 5 | zhob
# Processing Record 20 of Set 5 | castro
# Processing Record 21 of Set 5 | cabo san lucas
# Processing Record 22 of Set 5 | batagay-alyta
# Processing Record 23 of Set 5 | pucallpa
# Processing Record 24 of Set 5 | skeldon
# Processing Record 25 of Set 5 | faya
# Processing Record 26 of Set 5 | saleaula
# City saleaula not found. Skipping...
# Processing Record 27 of Set 5 | galgani
# City galgani not found. Skipping...
# Processing Record 28 of Set 5 | severomorsk
# Processing Record 29 of Set 5 | itoman
# Processing Record 30 of Set 5 | vikindu
# Processing Record 31 of Set 5 | ous
# Processing Record 32 of Set 5 | enshi
# Processing Record 33 of Set 5 | san pedro
# Processing Record 34 of Set 5 | barentsburg
# City barentsburg not found. Skipping...
# Processing Record 35 of Set 5 | faro
# Processing Record 36 of Set 5 | tunduru
# City tunduru not found. Skipping...
# Processing Record 37 of Set 5 | madimba
# Processing Record 38 of Set 5 | piritiba
# Processing Record 39 of Set 5 | chumikan
# Processing Record 40 of Set 5 | dargaville
# Processing Record 41 of Set 5 | mersing
# Processing Record 42 of Set 5 | navlya
# Processing Record 43 of Set 5 | garissa
# Processing Record 44 of Set 5 | zhanatas
# City zhanatas not found. Skipping...
# Processing Record 45 of Set 5 | khartoum
# Processing Record 46 of Set 5 | chiscani
# Processing Record 47 of Set 5 | khasan
# Processing Record 48 of Set 5 | walvis bay
# Processing Record 49 of Set 5 | nara
# Processing Record 50 of Set 5 | florence
# Processing Record 1 of Set 6 | lagoa
# Processing Record 2 of Set 6 | hasaki
# Processing Record 3 of Set 6 | carnarvon
# Processing Record 4 of Set 6 | chuy
# Processing Record 5 of Set 6 | bokspits
# City bokspits not found. Skipping...
# Processing Record 6 of Set 6 | nocupetaro
# Processing Record 7 of Set 6 | kassala
# Processing Record 8 of Set 6 | moreira sales
# Processing Record 9 of Set 6 | russell
# Processing Record 10 of Set 6 | wad madani
# Processing Record 11 of Set 6 | ijaki
# City ijaki not found. Skipping...
# Processing Record 12 of Set 6 | pisco
# Processing Record 13 of Set 6 | muros
# Processing Record 14 of Set 6 | peniche
# Processing Record 15 of Set 6 | saint anthony
# Processing Record 16 of Set 6 | tamworth
# Processing Record 17 of Set 6 | sorland
# Processing Record 18 of Set 6 | malwan
# City malwan not found. Skipping...
# Processing Record 19 of Set 6 | shubarkuduk
# Processing Record 20 of Set 6 | brewster
# Processing Record 21 of Set 6 | carutapera
# Processing Record 22 of Set 6 | seymchan
# Processing Record 23 of Set 6 | imbituba
# Processing Record 24 of Set 6 | vardo
# Processing Record 25 of Set 6 | buala
# Processing Record 26 of Set 6 | meulaboh
# Processing Record 27 of Set 6 | barawe
# City barawe not found. Skipping...
# Processing Record 28 of Set 6 | awbari
# Processing Record 29 of Set 6 | yar-sale
# Processing Record 30 of Set 6 | nizhneyansk
# City nizhneyansk not found. Skipping...
# Processing Record 31 of Set 6 | villa rica
# Processing Record 32 of Set 6 | disna
# Processing Record 33 of Set 6 | bontang
# Processing Record 34 of Set 6 | buriti alegre
# Processing Record 35 of Set 6 | airai
# Processing Record 36 of Set 6 | santiago do cacem
# Processing Record 37 of Set 6 | ruatoria
# City ruatoria not found. Skipping...
# Processing Record 38 of Set 6 | coihaique
# Processing Record 39 of Set 6 | sabang
# Processing Record 40 of Set 6 | nome
# Processing Record 41 of Set 6 | kulhudhuffushi
# Processing Record 42 of Set 6 | skjervoy
# Processing Record 43 of Set 6 | kavaratti
# Processing Record 44 of Set 6 | fernley
# Processing Record 45 of Set 6 | beloha
# Processing Record 46 of Set 6 | bonavista
# Processing Record 47 of Set 6 | vestmannaeyjar
# Processing Record 48 of Set 6 | mehran
# Processing Record 49 of Set 6 | leningradskiy
# Processing Record 50 of Set 6 | karaton
# Processing Record 1 of Set 7 | funes
# Processing Record 2 of Set 7 | victor harbor
# Processing Record 3 of Set 7 | morganton
# Processing Record 4 of Set 7 | culebra
# Processing Record 5 of Set 7 | sangar
# Processing Record 6 of Set 7 | rexburg
# Processing Record 7 of Set 7 | ust-kamchatsk
# City ust-kamchatsk not found. Skipping...
# Processing Record 8 of Set 7 | brokopondo
# Processing Record 9 of Set 7 | bilma
# Processing Record 10 of Set 7 | bubaque
# Processing Record 11 of Set 7 | aktau
# Processing Record 12 of Set 7 | tabou
# Processing Record 13 of Set 7 | kinkala
# Processing Record 14 of Set 7 | khandyga
# Processing Record 15 of Set 7 | darnah
# Processing Record 16 of Set 7 | tottori
# Processing Record 17 of Set 7 | vila velha
# Processing Record 18 of Set 7 | tiksi
# Processing Record 19 of Set 7 | gazli
# Processing Record 20 of Set 7 | olafsvik
# Processing Record 21 of Set 7 | xining
# Processing Record 22 of Set 7 | sinjai
# Processing Record 23 of Set 7 | severo-kurilsk
# Processing Record 24 of Set 7 | smirnykh
# Processing Record 25 of Set 7 | kalemie
# Processing Record 26 of Set 7 | hulan
# Processing Record 27 of Set 7 | esperance
# Processing Record 28 of Set 7 | yarada
# Processing Record 29 of Set 7 | taltal
# Processing Record 30 of Set 7 | burgeo
# Processing Record 31 of Set 7 | liverpool
# Processing Record 32 of Set 7 | otradnoye
# Processing Record 33 of Set 7 | havelock
# Processing Record 34 of Set 7 | filimonovo
# Processing Record 35 of Set 7 | tigil
# Processing Record 36 of Set 7 | san quintin
# Processing Record 37 of Set 7 | makakilo city
# Processing Record 38 of Set 7 | cururupu
# Processing Record 39 of Set 7 | nanakuli
# Processing Record 40 of Set 7 | srivardhan
# Processing Record 41 of Set 7 | yumen
# Processing Record 42 of Set 7 | pangai
# Processing Record 43 of Set 7 | quelimane
# Processing Record 44 of Set 7 | yeovil
# Processing Record 45 of Set 7 | ilulissat
# Processing Record 46 of Set 7 | vila franca do campo
# Processing Record 47 of Set 7 | ilheus
# Processing Record 48 of Set 7 | benghazi
# Processing Record 49 of Set 7 | kondinskoye
# Processing Record 50 of Set 7 | viedma
# Processing Record 1 of Set 8 | sao joao da barra
# Processing Record 2 of Set 8 | kaitangata
# Processing Record 3 of Set 8 | madison
# Processing Record 4 of Set 8 | shenjiamen
# Processing Record 5 of Set 8 | sitka
# Processing Record 6 of Set 8 | bangahan
# Processing Record 7 of Set 8 | srandakan
# Processing Record 8 of Set 8 | neon karlovasion
# Processing Record 9 of Set 8 | flin flon
# Processing Record 10 of Set 8 | subacius
# City subacius not found. Skipping...
# Processing Record 11 of Set 8 | axim
# Processing Record 12 of Set 8 | erenhot
# Processing Record 13 of Set 8 | sisimiut
# Processing Record 14 of Set 8 | tasiilaq
# Processing Record 15 of Set 8 | khormuj
# City khormuj not found. Skipping...
# Processing Record 16 of Set 8 | bereda
# Processing Record 17 of Set 8 | dunedin
# Processing Record 18 of Set 8 | burnie
# Processing Record 19 of Set 8 | uwayl
# City uwayl not found. Skipping...
# Processing Record 20 of Set 8 | luderitz
# Processing Record 21 of Set 8 | krasnaya gora
# Processing Record 22 of Set 8 | lihula
# Processing Record 23 of Set 8 | anadyr
# Processing Record 24 of Set 8 | prince rupert
# Processing Record 25 of Set 8 | shenandoah
# Processing Record 26 of Set 8 | tongzi
# Processing Record 27 of Set 8 | ketchikan
# Processing Record 28 of Set 8 | srednekolymsk
# Processing Record 29 of Set 8 | umm lajj
# Processing Record 30 of Set 8 | aljezur
# Processing Record 31 of Set 8 | camocim
# Processing Record 32 of Set 8 | bud
# Processing Record 33 of Set 8 | moctezuma
# Processing Record 34 of Set 8 | maposeni
# Processing Record 35 of Set 8 | muli
# Processing Record 36 of Set 8 | kieta
# Processing Record 37 of Set 8 | amderma
# City amderma not found. Skipping...
# Processing Record 38 of Set 8 | tabory
# Processing Record 39 of Set 8 | itarema
# Processing Record 40 of Set 8 | kaele
# Processing Record 41 of Set 8 | saint-joseph
# Processing Record 42 of Set 8 | mutsamudu
# City mutsamudu not found. Skipping...
# Processing Record 43 of Set 8 | havre-saint-pierre
# Processing Record 44 of Set 8 | polewali
# Processing Record 45 of Set 8 | lufkin
# Processing Record 46 of Set 8 | humboldt
# Processing Record 47 of Set 8 | poum
# Processing Record 48 of Set 8 | doha
# Processing Record 49 of Set 8 | lebu
# Processing Record 50 of Set 8 | egvekinot
# Processing Record 1 of Set 9 | phangnga
# Processing Record 2 of Set 9 | mitsamiouli
# Processing Record 3 of Set 9 | samarai
# Processing Record 4 of Set 9 | umm kaddadah
# Processing Record 5 of Set 9 | bismil
# Processing Record 6 of Set 9 | la ronge
# Processing Record 7 of Set 9 | la plata
# Processing Record 8 of Set 9 | sorkjosen
# Processing Record 9 of Set 9 | palatka
# Processing Record 10 of Set 9 | victoria
# Processing Record 11 of Set 9 | shingu
# Processing Record 12 of Set 9 | sengiley
# Processing Record 13 of Set 9 | chokurdakh
# Processing Record 14 of Set 9 | kayes
# Processing Record 15 of Set 9 | nanortalik
# Processing Record 16 of Set 9 | fianarantsoa
# Processing Record 17 of Set 9 | kuche
# City kuche not found. Skipping...
# Processing Record 18 of Set 9 | terrasini
# Processing Record 19 of Set 9 | sogdiondon
# City sogdiondon not found. Skipping...
# Processing Record 20 of Set 9 | winneba
# Processing Record 21 of Set 9 | pasni
# Processing Record 22 of Set 9 | sedelnikovo
# City sedelnikovo not found. Skipping...
# Processing Record 23 of Set 9 | mandapam
# Processing Record 24 of Set 9 | magadan
# Processing Record 25 of Set 9 | lata
# Processing Record 26 of Set 9 | davila
# Processing Record 27 of Set 9 | honiara
# Processing Record 28 of Set 9 | bambanglipuro
# Processing Record 29 of Set 9 | palabuhanratu
# City palabuhanratu not found. Skipping...
# Processing Record 30 of Set 9 | satun
# Processing Record 31 of Set 9 | wamba
# Processing Record 32 of Set 9 | nago
# Processing Record 33 of Set 9 | alice springs
# Processing Record 34 of Set 9 | shakawe
# Processing Record 35 of Set 9 | puerto del rosario
# Processing Record 36 of Set 9 | havoysund
# Processing Record 37 of Set 9 | hokitika
# Processing Record 38 of Set 9 | bejar
# Processing Record 39 of Set 9 | yomou
# Processing Record 40 of Set 9 | bin qirdan
# Processing Record 41 of Set 9 | melville
# Processing Record 42 of Set 9 | leavenworth
# Processing Record 43 of Set 9 | guatire
# Processing Record 44 of Set 9 | kenai
# Processing Record 45 of Set 9 | matara
# Processing Record 46 of Set 9 | louisbourg
# City louisbourg not found. Skipping...
# Processing Record 47 of Set 9 | alakurtti
# Processing Record 48 of Set 9 | san policarpo
# Processing Record 49 of Set 9 | tomatlan
# Processing Record 50 of Set 9 | teluknaga
# Processing Record 1 of Set 10 | grootfontein
# Processing Record 2 of Set 10 | gigmoto
# Processing Record 3 of Set 10 | sungurlu
# Processing Record 4 of Set 10 | jiddah
# City jiddah not found. Skipping...
# Processing Record 5 of Set 10 | lovington
# Processing Record 6 of Set 10 | contamana
# Processing Record 7 of Set 10 | japura
# Processing Record 8 of Set 10 | kentau
# Processing Record 9 of Set 10 | komsomolskiy
# Processing Record 10 of Set 10 | mayumba
# Processing Record 11 of Set 10 | katsuura
# Processing Record 12 of Set 10 | bouca
# Processing Record 13 of Set 10 | peruwelz
# Processing Record 14 of Set 10 | omsukchan
# Processing Record 15 of Set 10 | nioro
# Processing Record 16 of Set 10 | alofi
# Processing Record 17 of Set 10 | asau
# Processing Record 18 of Set 10 | manokwari
# Processing Record 19 of Set 10 | saint quentin
# City saint quentin not found. Skipping...
# Processing Record 20 of Set 10 | douglas
# Processing Record 21 of Set 10 | solyanka
# Processing Record 22 of Set 10 | muzhi
# Processing Record 23 of Set 10 | primorsk
# Processing Record 24 of Set 10 | aklavik
# Processing Record 25 of Set 10 | halifax
# Processing Record 26 of Set 10 | zhigansk
# Processing Record 27 of Set 10 | tazovskiy
# Processing Record 28 of Set 10 | salo
# Processing Record 29 of Set 10 | karratha
# Processing Record 30 of Set 10 | sinnamary
# Processing Record 31 of Set 10 | aripuana
# Processing Record 32 of Set 10 | platteville
# Processing Record 33 of Set 10 | linares
# Processing Record 34 of Set 10 | codrington
# Processing Record 35 of Set 10 | rio grande
# Processing Record 36 of Set 10 | cayenne
# Processing Record 37 of Set 10 | warwick
# Processing Record 38 of Set 10 | haines junction
# Processing Record 39 of Set 10 | maple creek
# Processing Record 40 of Set 10 | vila do maio
# Processing Record 41 of Set 10 | masallatah
# Processing Record 42 of Set 10 | sambava
# Processing Record 43 of Set 10 | grindavik
# Processing Record 44 of Set 10 | sirjan
# Processing Record 45 of Set 10 | bengkulu
# Processing Record 46 of Set 10 | valdivia
# Processing Record 47 of Set 10 | dukat
# Processing Record 48 of Set 10 | umzimvubu
# City umzimvubu not found. Skipping...
# Processing Record 49 of Set 10 | quatre cocos
# Processing Record 50 of Set 10 | torbay
# Processing Record 1 of Set 11 | college
# Processing Record 2 of Set 11 | vallenar
# Processing Record 3 of Set 11 | san antonio
# Processing Record 4 of Set 11 | portland
# Processing Record 5 of Set 11 | inta
# Processing Record 6 of Set 11 | kozluk
# Processing Record 7 of Set 11 | bodden town
# Processing Record 8 of Set 11 | palana
# Processing Record 9 of Set 11 | husavik
# Processing Record 10 of Set 11 | talah
# City talah not found. Skipping...
# Processing Record 11 of Set 11 | pavilosta
# Processing Record 12 of Set 11 | oranjemund
# Processing Record 13 of Set 11 | vanavara
# Processing Record 14 of Set 11 | san julian
# Processing Record 15 of Set 11 | provideniya
# Processing Record 16 of Set 11 | prescot
# Processing Record 17 of Set 11 | sulangan
# Processing Record 18 of Set 11 | mbuji-mayi
# Processing Record 19 of Set 11 | sentyabrskiy
# City sentyabrskiy not found. Skipping...
# Processing Record 20 of Set 11 | teknaf
# Processing Record 21 of Set 11 | sept-iles
# Processing Record 22 of Set 11 | vysokogornyy
# Processing Record 23 of Set 11 | port moresby
# Processing Record 24 of Set 11 | madang
# Processing Record 25 of Set 11 | newport
# Processing Record 26 of Set 11 | atar
# Processing Record 27 of Set 11 | bundaberg
# Processing Record 28 of Set 11 | sakakah
# Processing Record 29 of Set 11 | mehamn
# Processing Record 30 of Set 11 | parit buntar
# Processing Record 31 of Set 11 | kutum
# Processing Record 32 of Set 11 | solano
# Processing Record 33 of Set 11 | qui nhon
# Processing Record 34 of Set 11 | rubizhne
# Processing Record 35 of Set 11 | naters
# Processing Record 36 of Set 11 | tsabong
# Processing Record 37 of Set 11 | dhidhdhoo
# Processing Record 38 of Set 11 | pitimbu
# Processing Record 39 of Set 11 | santa marta
# Processing Record 40 of Set 11 | matucana
# Processing Record 41 of Set 11 | villa carlos paz
# Processing Record 42 of Set 11 | cidreira
# Processing Record 43 of Set 11 | dingle
# Processing Record 44 of Set 11 | ambanja
# Processing Record 45 of Set 11 | kudahuvadhoo
# Processing Record 46 of Set 11 | tazmalt
# Processing Record 47 of Set 11 | arona
# Processing Record 48 of Set 11 | hami
# Processing Record 49 of Set 11 | sarangani
# Processing Record 50 of Set 11 | henties bay
# Processing Record 1 of Set 12 | leh
# Processing Record 2 of Set 12 | mancio lima
# Processing Record 3 of Set 12 | rolim de moura
# City rolim de moura not found. Skipping...
# Processing Record 4 of Set 12 | olinda
# Processing Record 5 of Set 12 | kindu
# Processing Record 6 of Set 12 | wageningen
# Processing Record 7 of Set 12 | campbell river
# Processing Record 8 of Set 12 | omboue
# Processing Record 9 of Set 12 | bo phloi
# Processing Record 10 of Set 12 | hovd
# Processing Record 11 of Set 12 | leshukonskoye
# Processing Record 12 of Set 12 | beya
# Processing Record 13 of Set 12 | katsina
# Processing Record 14 of Set 12 | birao
# Processing Record 15 of Set 12 | onega
# Processing Record 16 of Set 12 | kjollefjord
# Processing Record 17 of Set 12 | los llanos de aridane
# Processing Record 18 of Set 12 | venice
# Processing Record 19 of Set 12 | phan thiet
# Processing Record 20 of Set 12 | tura
# Processing Record 21 of Set 12 | miri
# Processing Record 22 of Set 12 | coquimbo
# Processing Record 23 of Set 12 | vzmorye
# Processing Record 24 of Set 12 | opuwo
# Processing Record 25 of Set 12 | padang
# Processing Record 26 of Set 12 | anderson
# Processing Record 27 of Set 12 | grand centre
# City grand centre not found. Skipping...
# Processing Record 28 of Set 12 | bara
# Processing Record 29 of Set 12 | boa vista
# Processing Record 30 of Set 12 | labuan
# Processing Record 31 of Set 12 | sarai mir
# Processing Record 32 of Set 12 | ojinaga
# Processing Record 33 of Set 12 | fare
# Processing Record 34 of Set 12 | trumbull
# Processing Record 35 of Set 12 | arinos
# Processing Record 36 of Set 12 | camana
# Processing Record 37 of Set 12 | batsfjord
# Processing Record 38 of Set 12 | emba
# Processing Record 39 of Set 12 | ust-ordynskiy
# Processing Record 40 of Set 12 | kuusamo
# Processing Record 41 of Set 12 | sinop
# Processing Record 42 of Set 12 | rorvik
# Processing Record 43 of Set 12 | samalaeulu
# City samalaeulu not found. Skipping...
# Processing Record 44 of Set 12 | atherton
# Processing Record 45 of Set 12 | temecula
# Processing Record 46 of Set 12 | koslan
# Processing Record 47 of Set 12 | kirkenaer
# Processing Record 48 of Set 12 | dagua
# Processing Record 49 of Set 12 | lubango
# Processing Record 50 of Set 12 | ambodifototra
# City ambodifototra not found. Skipping...
# Processing Record 1 of Set 13 | veliki preslav
# Processing Record 2 of Set 13 | adrar
# Processing Record 3 of Set 13 | marshall
# Processing Record 4 of Set 13 | yomitan
# City yomitan not found. Skipping...
# Processing Record 5 of Set 13 | talakan
# Processing Record 6 of Set 13 | mandera
# Processing Record 7 of Set 13 | eirunepe
# Processing Record 8 of Set 13 | lucatan
# City lucatan not found. Skipping...
# Processing Record 9 of Set 13 | tanout
# Processing Record 10 of Set 13 | loiza
# Processing Record 11 of Set 13 | kilimatinde
# Processing Record 12 of Set 13 | ahuimanu
# Processing Record 13 of Set 13 | xuddur
# Processing Record 14 of Set 13 | buin
# Processing Record 15 of Set 13 | nhulunbuy
# Processing Record 16 of Set 13 | itagi
# Processing Record 17 of Set 13 | casas grandes
# Processing Record 18 of Set 13 | jagtial
# Processing Record 19 of Set 13 | mount gambier
# Processing Record 20 of Set 13 | khani
# Processing Record 21 of Set 13 | westport
# Processing Record 22 of Set 13 | seymour
# Processing Record 23 of Set 13 | elko
# Processing Record 24 of Set 13 | san juan
# Processing Record 25 of Set 13 | placido de castro
# Processing Record 26 of Set 13 | kathmandu
# Processing Record 27 of Set 13 | stuttgart
# Processing Record 28 of Set 13 | soto la marina
# Processing Record 29 of Set 13 | puerto vallarta
# Processing Record 30 of Set 13 | damara
# Processing Record 31 of Set 13 | ponta delgada
# Processing Record 32 of Set 13 | umm durman
# City umm durman not found. Skipping...
# Processing Record 33 of Set 13 | tidore
# City tidore not found. Skipping...
# Processing Record 34 of Set 13 | takoradi
# Processing Record 35 of Set 13 | sabha
# Processing Record 36 of Set 13 | inyonga
# Processing Record 37 of Set 13 | mill valley
# Processing Record 38 of Set 13 | morris
# Processing Record 39 of Set 13 | gwadar
# Processing Record 40 of Set 13 | mecca
# Processing Record 41 of Set 13 | arlit
# Processing Record 42 of Set 13 | yefremov
# Processing Record 43 of Set 13 | loralai
# Processing Record 44 of Set 13 | kruisfontein
# Processing Record 45 of Set 13 | bridlington
# Processing Record 46 of Set 13 | aybak
# City aybak not found. Skipping...
# Processing Record 47 of Set 13 | ishigaki
# Processing Record 48 of Set 13 | atkarsk
# Processing Record 49 of Set 13 | alexandria
# Processing Record 50 of Set 13 | haverfordwest
# Processing Record 1 of Set 14 | inndyr
# Processing Record 2 of Set 14 | mbanza-ngungu
# Processing Record 3 of Set 14 | yatou
# Processing Record 4 of Set 14 | monrovia
# Processing Record 5 of Set 14 | clyde river
# Processing Record 6 of Set 14 | richards bay
# Processing Record 7 of Set 14 | yining
# Processing Record 8 of Set 14 | warqla
# City warqla not found. Skipping...
# Processing Record 9 of Set 14 | mao
# Processing Record 10 of Set 14 | saint thomas
# Processing Record 11 of Set 14 | beian
# Processing Record 12 of Set 14 | jesus carranza
# Processing Record 13 of Set 14 | lorengau
# Processing Record 14 of Set 14 | chibombo
# Processing Record 15 of Set 14 | kasempa
# Processing Record 16 of Set 14 | santa isabel
# Processing Record 17 of Set 14 | altay
# Processing Record 18 of Set 14 | berwick
# Processing Record 19 of Set 14 | saint-pierre
# Processing Record 20 of Set 14 | cape coast
# Processing Record 21 of Set 14 | ndende
# Processing Record 22 of Set 14 | homer
# Processing Record 23 of Set 14 | sao filipe
# Processing Record 24 of Set 14 | zyryanka
# Processing Record 25 of Set 14 | hunterville
# Processing Record 26 of Set 14 | kamenka
# Processing Record 27 of Set 14 | tocopilla
# Processing Record 28 of Set 14 | zvishavane
# Processing Record 29 of Set 14 | antalaha
# Processing Record 30 of Set 14 | jabinyanah
# Processing Record 31 of Set 14 | nabire
# Processing Record 32 of Set 14 | talaya
# Processing Record 33 of Set 14 | soyo
# Processing Record 34 of Set 14 | sakit
# Processing Record 35 of Set 14 | ngunguru
# Processing Record 36 of Set 14 | sobolevo
# Processing Record 37 of Set 14 | altar
# Processing Record 38 of Set 14 | sanary-sur-mer
# Processing Record 39 of Set 14 | longlac
# City longlac not found. Skipping...
# Processing Record 40 of Set 14 | susanville
# Processing Record 41 of Set 14 | iquique
# Processing Record 42 of Set 14 | nanhai
# Processing Record 43 of Set 14 | rio branco do sul
# Processing Record 44 of Set 14 | monteagudo
# Processing Record 45 of Set 14 | kenitra
# Processing Record 46 of Set 14 | midland
# Processing Record 47 of Set 14 | katobu
# Processing Record 48 of Set 14 | araouane
# Processing Record 49 of Set 14 | dwarka
# Processing Record 50 of Set 14 | ahumada
# City ahumada not found. Skipping...
# Processing Record 1 of Set 15 | namatanai
# Processing Record 2 of Set 15 | fairbanks
# Processing Record 3 of Set 15 | vigrestad
# Processing Record 4 of Set 15 | rudsar
# Processing Record 5 of Set 15 | najran
# Processing Record 6 of Set 15 | azimur
# City azimur not found. Skipping...
# Processing Record 7 of Set 15 | ako
# Processing Record 8 of Set 15 | rudnogorsk
# Processing Record 9 of Set 15 | graaff-reinet
# Processing Record 10 of Set 15 | parkes
# Processing Record 11 of Set 15 | altamira
# Processing Record 12 of Set 15 | himora
# City himora not found. Skipping...
# Processing Record 13 of Set 15 | usevya
# Processing Record 14 of Set 15 | dzhusaly
# City dzhusaly not found. Skipping...
# Processing Record 15 of Set 15 | manaus
# Processing Record 16 of Set 15 | tabiauea
# City tabiauea not found. Skipping...
# Processing Record 17 of Set 15 | acajutla
# Processing Record 18 of Set 15 | lumphat
# Processing Record 19 of Set 15 | fallon
# Processing Record 20 of Set 15 | barra da estiva
# Processing Record 21 of Set 15 | san borja
# Processing Record 22 of Set 15 | berbera
# Processing Record 23 of Set 15 | prado
# Processing Record 24 of Set 15 | odweyne
# Processing Record 25 of Set 15 | tilichiki
# Processing Record 26 of Set 15 | vicuna
# Processing Record 27 of Set 15 | lancaster
# Processing Record 28 of Set 15 | kirakira
# Processing Record 29 of Set 15 | ipixuna
# Processing Record 30 of Set 15 | vagay
# Processing Record 31 of Set 15 | pathri
# Processing Record 32 of Set 15 | zlocieniec
# Processing Record 33 of Set 15 | uray
# Processing Record 34 of Set 15 | kloulklubed
# Processing Record 35 of Set 15 | buqayq
# City buqayq not found. Skipping...
# Processing Record 36 of Set 15 | urubicha
# Processing Record 37 of Set 15 | urumqi
# Processing Record 38 of Set 15 | dera bugti
# Processing Record 39 of Set 15 | santa cruz
# Processing Record 40 of Set 15 | karaul
# City karaul not found. Skipping...
# Processing Record 41 of Set 15 | nigde
# Processing Record 42 of Set 15 | ust-tsilma
# Processing Record 43 of Set 15 | eucaliptus
# Processing Record 44 of Set 15 | muzquiz
# City muzquiz not found. Skipping...
# Processing Record 45 of Set 15 | itaueira
# Processing Record 46 of Set 15 | mizque
# Processing Record 47 of Set 15 | mirador
# Processing Record 48 of Set 15 | bonthe
# Processing Record 49 of Set 15 | tumannyy
# City tumannyy not found. Skipping...
# Processing Record 50 of Set 15 | nogliki
# Processing Record 1 of Set 16 | paamiut
# Processing Record 2 of Set 16 | bargal
# City bargal not found. Skipping...
# Processing Record 3 of Set 16 | montecristo
# Processing Record 4 of Set 16 | lewistown
# Processing Record 5 of Set 16 | saint-francois
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_weather_df = pd.DataFrame(city_data)
city_weather_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Yenagoa      NG   4.92    6.26     74.84        90          99
# 1    Oktyabrskoye      RU  43.06   44.74     53.60        93           8
# 2             Gat      IL  31.61   34.76     73.00        27           0
# 3  Saint-Philippe      RE -21.36   55.77     68.00        60          45
# 4    Ornskoldsvik      SE  63.29   18.72     41.00        86           1
# 5          Harper      LR   4.38   -7.72     74.97        86          98
# 6           Kapaa      US  22.08 -159.32     84.20        66          20
# 7          Marawi      PH   8.00  124.29     87.01        67          67
# 8          Vanimo      PG  -2.67  141.30     84.88        72          49
# 9          Hobart      AU -42.88  147.33     61.00        38          40
#
#    Wind Speed Current Description
# 0        4.05     overcast clouds
# 1        4.47           clear sky
# 2        1.99           clear sky
# 3        8.05    scattered clouds
# 4        5.82           clear sky
# 5        8.05     overcast clouds
# 6       12.75          few clouds
# 7        4.00          light rain
# 8        7.29          light rain
# 9       23.04          light rain

# %%
# Export the City_Data into a CSV.
city_weather_df.to_csv('WeatherPy_Database.csv', index_label='City_ID')
